# %%
from nameparser import HumanName
import numpy as np

# %%
data = [
    "HANI ASAAD",
    "Anas Raqi",
    "Divya Mukundan",
    "SWATI MISHRA",
    "Awn albuhairy",
    "L D Satish Kumar",
    "Pramila basnet",
    "RaJ Chaudhary",
    "Raship Chhabra",
    "Arjun V",
    "Saad Al-Taher",
    "Mohammad Ayman",
    "Yasar Khan",
    "Mohamed Fahmy",
    # "Odai Nawafleh",
    # "Kareem Moussa",
    # "Mennah Azab",
    # "Pratik Chowdhury",
    # "Issam EL HADDIOUI",
    # "Aravind Raj",
    # "Hana Thaer",
    # "Ahmad Maher",
    # "Imperial MBA, MSc, NSE4, CEH",
    # "Nitin Kapil",
    # "George Francis",
    # "SACHU CHANDRAN",
    # "Ishtiyak Surve",
    # "Moataz Madkour",
    # "Kamel Zalt ✔️",
    # "ENGR MUHAMMAD REHAN",
    "Mohammed Jamal"
]

# %%
for data_i in data:
    data_i = " ".join([name.capitalize() for name in data_i.split()])
    print(data_i)
    
    name = HumanName(data_i)
    first , middle, last = name['first'], name['middle'], name['last']
    
    notAlloweds = ["muhammad", "mohammad", "mohammed", "muhammed", "mohamed", "muhamed"]
    
    for notAllowed in notAlloweds:
        if notAllowed in first.lower() : first = ""
        if notAllowed in middle.lower() : middle = ""
    
    listed = [first , middle, last]
    print(listed)
    applicant = listed[ np.argmax([len(first), len(middle), len(last)-2]) ]
    
    print(applicant, "\n")
# Out:
# Hani Asaad
# ['Hani', '', 'Asaad']
# Hani
#
# Anas Raqi
# ['Anas', '', 'Raqi']
# Anas
#
# Divya Mukundan
# ['Divya', '', 'Mukundan']
# Mukundan
#
# Swati Mishra
# ['Swati', '', 'Mishra']
# Swati
#
# Awn Albuhairy
# ['Awn', '', 'Albuhairy']
# Albuhairy
#
# L D Satish Kumar
# ['L', 'D Satish', 'Kumar']
# D Satish
#
# Pramila Basnet
# ['Pramila', '', 'Basnet']
# Pramila
#
# Raj Chaudhary
# ['Raj', '', 'Chaudhary']
# Chaudhary
#
# Raship Chhabra
# ['Raship', '', 'Chhabra']
# Raship
#
# Arjun V
# ['Arjun', '', 'V']
# Arjun
#
# Saad Al-taher
# ['Saad', '', 'Al-taher']
# Al-taher
#
# Mohammad Ayman
# ['', '', 'Ayman']
# Ayman
#
# Yasar Khan
# ['Yasar', '', 'Khan']
# Yasar
#
# Mohamed Fahmy
# ['', '', 'Fahmy']
# Fahmy
#
# Mohammed Jamal
# ['', '', 'Jamal']
# Jamal

# %%
data2 = [
    "Harmain Iqbal",
    "Buxial Khan",
    "Aminah Noman",
    "Hafsa Tariq",
    "Fareed Asif",
    "STariq Shah Gilani",
    "Bilal Laiq",
    "ENGINEER MUHAMMAD REHAN",
    "Muneer Siddiqui",
    "Maryam Khan",
    "Abdul Haseeb Khan",
    "Zohaib Ali",
    "Aliza Farrukh",
    "Dhani Bakhsh Magsi",
    "Sohaib Hussain Shaikh",
    "Ashar Hashmi",
    "Muhammad Muneeb Khan",
    "Nimra Chauhan",
    "Agha Ali Aziz Khan",
    "Saif Khan",
    "Adil Ali",
    "Syeda Rimsha Bukhari",
    "Alishba Masood",
    "Sohrab Khan Brohi",
    "Qazi Muhammad Nasir",
    "Abdul Rehman Lodhi",
    "Asif Ali",
    "Zaki Abbas",
    "Syed Mujeeb Ur Rehman Shah",
    "Fariha Rafique",
    "Shiza Nadeem Baig",
    "Burhan Khanzada",
    "Eman khan",
    "Aijaz Muhammad Usmani",
    "Fahad Sadiq",
    "Najaf Ali",
    "Inamullah Qaisrani",
    "Ahsan Siddiqui",
    "Tahira Jabeen",
    "Waqas Rehman",
    "FAISAL KHAN",
    "Ahsan Hussain",
    "Mahad Amh",
    "Sibghat ullah Hamad",
    "Faryal K.",
    "Syeda Hooria",
    "Fariha Aziz",
    "Syed Mohammad",
    "Ehtesham Alvi",
    "Ayesha A.",
    "Salman Channa",
    "Tuba Ghafoor",
    "umar farooq",
    "Kashish Shewani",
    "Shahzaib Rajper",
    "Ahmed Hussain",
    "Saad Faisal",
    "Muhammad Areeb",
    "Syed Usama Ahmad Sohail",
    "Asif Ali",
    "Alishba khan",
    "Waleed Hassan",
    "Muhammad Danish",
    "Taha Hassan",
    "Murk Faiz",
    "Muhammad Ameer Hamza",
    "Syeda Manahil Faraz",
    "Syed Asim Ali",
    "Khushboo Zameer",
    "Maham Furqan",
    "Ahsan Zahid"
]

# %%
for data_i in data2:
    data_i = " ".join([name.capitalize() for name in data_i.split()])
    print(data_i)
    
    name = HumanName(data_i)
    first , middle, last = name['first'], name['middle'], name['last']
    
    
    notAlloweds = ["muhammad", "mohammad", "mohammed", "muhammed", "mohamed", "muhamed"]
    
    for notAllowed in notAlloweds:
        if notAllowed in first.lower() : first = ""
        if notAllowed in middle.lower() : middle = ""
        
    
    listed = [first , middle, last]
    print(listed)
    applicant = listed[ np.argmax([len(first), len(middle), len(last)-2]) ]
    
    print(applicant, "\n")
# Out:
# Harmain Iqbal
# ['Harmain', '', 'Iqbal']
# Harmain
#
# Buxial Khan
# ['Buxial', '', 'Khan']
# Buxial
#
# Aminah Noman
# ['Aminah', '', 'Noman']
# Aminah
#
# Hafsa Tariq
# ['Hafsa', '', 'Tariq']
# Hafsa
#
# Fareed Asif
# ['Fareed', '', 'Asif']
# Fareed
#
# Stariq Shah Gilani
# ['Stariq', 'Shah', 'Gilani']
# Stariq
#
# Bilal Laiq
# ['Bilal', '', 'Laiq']
# Bilal
#
# Engineer Muhammad Rehan
# ['', '', 'Rehan']
# Rehan
#
# Muneer Siddiqui
# ['Muneer', '', 'Siddiqui']
# Muneer
#
# Maryam Khan
# ['Maryam', '', 'Khan']
# Maryam
#
# Abdul Haseeb Khan
# ['Abdul', 'Haseeb', 'Khan']
# Haseeb
#
# Zohaib Ali
# ['Zohaib', '', 'Ali']
# Zohaib
#
# Aliza Farrukh
# ['Aliza', '', 'Farrukh']
# Aliza
#
# Dhani Bakhsh Magsi
# ['Dhani', 'Bakhsh', 'Magsi']
# Bakhsh
#
# Sohaib Hussain Shaikh
# ['Sohaib', 'Hussain', 'Shaikh']
# Hussain
#
# Ashar Hashmi
# ['Ashar', '', 'Hashmi']
# Ashar
#
# Muhammad Muneeb Khan
# ['', 'Muneeb', 'Khan']
# Muneeb
#
# Nimra Chauhan
# ['Nimra', '', 'Chauhan']
# Nimra
#
# Agha Ali Aziz Khan
# ['Agha', 'Ali Aziz', 'Khan']
# Ali Aziz
#
# Saif Khan
# ['Saif', '', 'Khan']
# Saif
#
# Adil Ali
# ['Adil', '', 'Ali']
# Adil
#
# Syeda Rimsha Bukhari
# ['Syeda', 'Rimsha', 'Bukhari']
# Rimsha
#
# Alishba Masood
# ['Alishba', '', 'Masood']
# Alishba
#
# Sohrab Khan Brohi
# ['Sohrab', 'Khan', 'Brohi']
# Sohrab
#
# Qazi Muhammad Nasir
# ['Qazi', '', 'Nasir']
# Qazi
#
# Abdul Rehman Lodhi
# ['Abdul', 'Rehman', 'Lodhi']
# Rehman
#
# Asif Ali
# ['Asif', '', 'Ali']
# Asif
#
# Zaki Abbas
# ['Zaki', '', 'Abbas']
# Zaki
#
# Syed Mujeeb Ur Rehman Shah
# ['Syed', 'Mujeeb Ur Rehman', 'Shah']
# Mujeeb Ur Rehman
#
# Fariha Rafique
# ['Fariha', '', 'Rafique']
# Fariha
#
# Shiza Nadeem Baig
# ['Shiza', 'Nadeem', 'Baig']
# Nadeem
#
# Burhan Khanzada
# ['Burhan', '', 'Khanzada']
# Burhan
#
# Eman Khan
# ['Eman', '', 'Khan']
# Eman
#
# Aijaz Muhammad Usmani
# ['Aijaz', '', 'Usmani']
# Aijaz
#
# Fahad Sadiq
# ['Fahad', '', 'Sadiq']
# Fahad
#
# Najaf Ali
# ['Najaf', '', 'Ali']
# Najaf
#
# Inamullah Qaisrani
# ['Inamullah', '', 'Qaisrani']
# Inamullah
#
# Ahsan Siddiqui
# ['Ahsan', '', 'Siddiqui']
# Siddiqui
#
# Tahira Jabeen
# ['Tahira', '', 'Jabeen']
# Tahira
#
# Waqas Rehman
# ['Waqas', '', 'Rehman']
# Waqas
#
# Faisal Khan
# ['Faisal', '', 'Khan']
# Faisal
#
# Ahsan Hussain
# ['Ahsan', '', 'Hussain']
# Ahsan
#
# Mahad Amh
# ['Mahad', '', 'Amh']
# Mahad
#
# Sibghat Ullah Hamad
# ['Sibghat', 'Ullah', 'Hamad']
# Sibghat
#
# Faryal K.
# ['Faryal', '', 'K.']
# Faryal
#
# Syeda Hooria
# ['Syeda', '', 'Hooria']
# Syeda
#
# Fariha Aziz
# ['Fariha', '', 'Aziz']
# Fariha
#
# Syed Mohammad
# ['Syed', '', 'Mohammad']
# Mohammad
#
# Ehtesham Alvi
# ['Ehtesham', '', 'Alvi']
# Ehtesham
#
# Ayesha A.
# ['Ayesha', '', 'A.']
# Ayesha
#
# Salman Channa
# ['Salman', '', 'Channa']
# Salman
#
# Tuba Ghafoor
# ['Tuba', '', 'Ghafoor']
# Ghafoor
#
# Umar Farooq
# ['Umar', '', 'Farooq']
# Umar
#
# Kashish Shewani
# ['Kashish', '', 'Shewani']
# Kashish
#
# Shahzaib Rajper
# ['Shahzaib', '', 'Rajper']
# Shahzaib
#
# Ahmed Hussain
# ['Ahmed', '', 'Hussain']
# Ahmed
#
# Saad Faisal
# ['Saad', '', 'Faisal']
# Saad
#
# Muhammad Areeb
# ['', '', 'Areeb']
# Areeb
#
# Syed Usama Ahmad Sohail
# ['Syed', 'Usama Ahmad', 'Sohail']
# Usama Ahmad
#
# Asif Ali
# ['Asif', '', 'Ali']
# Asif
#
# Alishba Khan
# ['Alishba', '', 'Khan']
# Alishba
#
# Waleed Hassan
# ['Waleed', '', 'Hassan']
# Waleed
#
# Muhammad Danish
# ['', '', 'Danish']
# Danish
#
# Taha Hassan
# ['Taha', '', 'Hassan']
# Taha
#
# Murk Faiz
# ['Murk', '', 'Faiz']
# Murk
#
# Muhammad Ameer Hamza
# ['', 'Ameer', 'Hamza']
# Ameer
#
# Syeda Manahil Faraz
# ['Syeda', 'Manahil', 'Faraz']
# Manahil
#
# Syed Asim Ali
# ['Syed', 'Asim', 'Ali']
# Syed
#
# Khushboo Zameer
# ['Khushboo', '', 'Zameer']
# Khushboo
#
# Maham Furqan
# ['Maham', '', 'Furqan']
# Maham
#
# Ahsan Zahid
# ['Ahsan', '', 'Zahid']
# Ahsan
