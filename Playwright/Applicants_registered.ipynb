# %%
import gspread
import pandas as pd
import openpyxl
import datetime

# %%
gc = gspread.oauth()
sh = gc.open("Associate: Ashar Saleem")
print(sh)
spreadsheet_data = gc.export(sh.id,gspread.utils.ExportFormat.CSV)
print("Excel created")

FILE_NAME = "FILES/Dashboard.csv"
SHEET = ""
FULLNAME = "Ashar Saleem"

# Write the binary data to a file
with open(FILE_NAME, 'wb') as file:
    file.write(spreadsheet_data)
# Out:
# <Spreadsheet 'Associate: Ashar Saleem' id:1ASWbNa3Yd0q4vac-0_i3vupPcfgVOMUM5hAKOHjgHeY>
# Excel created

# %%
df_new = pd.read_csv("FILES/Dashboard.csv", parse_dates=['signup_date'])
print(df_new.shape)
df_new = df_new.drop_duplicates(keep= "first", subset = "_id")
print(df_new.shape)
df_new.head()
# Out:
# (327, 37)
# (291, 37)
#                         _id       full_name signup_date  referrer_name  \
# 0  64dc58f0523152001e0ee1e5  Noor ul Hassan  2023-08-16            NaN
# 1  649f27f61b4a4b001d086f27    Monica Bruno  2023-06-30            NaN
# 2  64f1bb15c9c8bd001dda11ad     Saba Qaisar  2023-09-01            NaN
# 3  64de23b3247256001d5a51ef     waqar hyder  2023-08-17            NaN
# 4  64dc6966862274001de427ca       fady Samy  2023-08-16            NaN
#
#    application                        title                        name  \
# 0      applied             Sales Specialist  Empire Heights Properties
# 1      applied  Senior Marketing Specialist              Perfect Purity
# 2      applied               IT Coordinator        Alzayani Investments
# 3  Not applied                          NaN                         NaN
# 4  Not applied                          NaN                         NaN
#
#    onboardingstep aboutme1 profileheadline  ... gender photo phone_number  \
# 0             9.0      Yes             NaN  ...    NaN   NaN          Yes
# 1            13.0      NaN             NaN  ...    Yes   Yes          Yes
# 2             9.0      NaN             NaN  ...    NaN   NaN          NaN
# 3             9.0      Yes             NaN  ...    NaN   NaN          Yes
# 4             9.0      Yes             NaN  ...    NaN   NaN          Yes
#
#   languages secondaryemail whatsappnumber interested_in is_visa_required  \
# 0       NaN            NaN            Yes           Yes              Yes
# 1       NaN            Yes            NaN           NaN              Yes
# 2       NaN            NaN            NaN           NaN              NaN
# 3       NaN            Yes            Yes           Yes              Yes
# 4       NaN            NaN            NaN           Yes              Yes
#
#   salary_range Profile Completion %
# 0          Yes              100.00%
# 1          Yes               58.33%
# 2          NaN               41.67%
# 3          Yes              100.00%
# 4          Yes              100.00%
#
# [5 rows x 37 columns]

# %%
df_new['Current_Time'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df_new['Remaining Count'] = 3

df_new['ProfileCompletion'] = pd.to_numeric(df_new['Profile Completion %'].str.split('%', expand=True)[0])
df_new = df_new.sort_values(by=['signup_date'], axis=0, ascending=False)

# %% [markdown]
# ### How many new applicants in one week span

# %%
today = datetime.date.today()
PreviousMonday = today - datetime.timedelta(days=today.weekday(), weeks=1)

print(str(PreviousMonday))
PreviousMonday = "2023-09-01"
print(df_new[df_new['signup_date'] >= str(PreviousMonday)].shape)
# df_new[df_new['signup_date'] >= "2023-07-26" ]
# df_new[ (df_new['signup_date'] >= "2023-07-1") & (df_new['ProfileCompletion'] == 100)] .shape
df_new.loc[:,'signup_date_same'] = df_new['signup_date']
df_new.loc[:,'application_same'] = df_new['application']
df_new = df_new[df_new['signup_date'] >= str(PreviousMonday)]
# Out:
# 2023-09-18
# (63, 40)

# %%
df_new2 = df_new[df_new['ProfileCompletion'] == 100].reset_index(drop=True)
# df_new2 = df_new[df_new['onboardingstep'] == 13].reset_index(drop=True)
# df_new2 = df_new[df_new['application'] == 'applied'].reset_index(drop=True)
# df_new2 = df_new[(df_new['ProfileCompletion'] == 100)  & (df_new['application'] == 'applied')] .reset_index(drop=True)
print(len(df_new2)-3)
df_new.reset_index()[:30]
# Out:
# 43
#     index                       _id               full_name signup_date  \
# 0     205  6513ecba5b38f7001d6c200d          Mohammed Bayaz  2023-09-27
# 1     185  651274bbef73aa001da534d3         Mohammad Bashar  2023-09-26
# 2      76  6512ca5f881c9b001d4fec37               Safvan Vt  2023-09-26
# 3     323  65111816ebc35b001d6a123a         shafiq mohammed  2023-09-25
# 4     114  6511d846e2772d001de51744           Alex Varghese  2023-09-25
# 5      37  651111f79348f0001d78c621             AMALNADH NJ  2023-09-25
# 6     125  6511e08a4786f9001d29fc15  Edward Jerameel Martin  2023-09-25
# 7      52  6511def666c03e001dbe2f73     Kartiksingh Hushare  2023-09-25
# 8     287  650fad23b9e90b001dbf9a0f          Muhammed Shafi  2023-09-24
# 9     324  650fef799348f0001d784247      Syamlal Swarnappan  2023-09-24
# 10     71  65103b5723114b001de54884          shahbaz akhter  2023-09-24
# 11    182  650ff6303c8e50001c2005a8         Zawar Amin khan  2023-09-24
# 12    137  650fef4ddc22bd001dee27ce  Md. Saiful islam Ropam  2023-09-24
# 13    150  650fcf78781892001ddc3d2b            nabil sayyed  2023-09-24
# 14    261  650f145b9348f0001d77f41b       Jithesh.K.P Jithu  2023-09-23
# 15     45  650f216f0acb7b001d9321ce          Kartik Hushare  2023-09-23
# 16    128  650f1454cb796e001d5df4b3        Abu Bakar Waheed  2023-09-23
# 17    245  650f11c4ebc35b001d693ade             subin balan  2023-09-23
# 18     93  650f2636a5d55e001d5b51fd           Arun Raghavan  2023-09-23
# 19    127  650f0fc1135a25001da8ca36            Rehab Tigani  2023-09-23
# 20    147  650f3001290fef001d21d2c8     Charinette Padolina  2023-09-23
# 21    219  650f14b8290fef001d21a015        John Robert Susi  2023-09-23
# 22     16  650f0913cb796e001d5defc4              bino benny  2023-09-23
# 23    288  650f103b9348f0001d77f24e              Rashid Ali  2023-09-23
# 24    307  650f0237dc22bd001ded92dc               ali akbar  2023-09-23
# 25     40  650f05c85e8136001d98b8b6      Karren Jake Aenlle  2023-09-23
# 26    251  650597facf57b8001d761f8b            Gloria Koima  2023-09-16
# 27    253  65057a1412b009001ddda45a    Sayeeduddin Mohammed  2023-09-16
# 28     50  650580c4bf9692001d884645           Amitesh Rawat  2023-09-16
# 29     48  65008b7e1861b6001d6cb41c        Zohal Ahmad Shah  2023-09-12
#
#     referrer_name  application                      title  \
# 0             NaN      applied  Interior Design Draftsman
# 1             NaN  Not applied                        NaN
# 2             NaN      applied  Interior Design Draftsman
# 3             NaN      applied      Procurement Assistant
# 4             NaN      applied      Procurement Assistant
# 5             NaN      applied  Interior Design Draftsman
# 6             NaN      applied      Procurement Assistant
# 7             NaN  Not applied                        NaN
# 8             NaN  Not applied                        NaN
# 9             NaN      applied      Procurement Assistant
# 10            NaN      applied  Interior Design Draftsman
# 11            NaN      applied      Procurement Assistant
# 12            NaN  Not applied                        NaN
# 13            NaN      applied  Interior Design Draftsman
# 14            NaN  Not applied                        NaN
# 15            NaN      applied      Procurement Assistant
# 16            NaN  Not applied                        NaN
# 17            NaN      applied  Interior Design Draftsman
# 18            NaN  Not applied                        NaN
# 19            NaN      applied  Interior Design Draftsman
# 20            NaN      applied      Procurement Assistant
# 21            NaN      applied  Interior Design Draftsman
# 22            NaN      applied      Procurement Assistant
# 23            NaN      applied      Procurement Assistant
# 24            NaN  Not applied                        NaN
# 25            NaN      applied      Procurement Assistant
# 26            NaN      applied             Chief of Staff
# 27            NaN  Not applied                        NaN
# 28            NaN      applied             Chief of Staff
# 29            NaN  Not applied                        NaN
#
#                                                 name  onboardingstep aboutme1  \
# 0                                 Qureos Recruitment             9.0      NaN
# 1                                                NaN             2.0      NaN
# 2                                 Qureos Recruitment             9.0      Yes
# 3                        ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 4                        ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 5                                 Qureos Recruitment             9.0      Yes
# 6                        ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 7                                                NaN             1.0      NaN
# 8                                                NaN             2.0      NaN
# 9                        ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 10                                Qureos Recruitment             9.0      Yes
# 11                       ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 12                                               NaN             9.0      Yes
# 13                                Qureos Recruitment             9.0      Yes
# 14                                               NaN             1.0      NaN
# 15                       ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 16                                               NaN             2.0      NaN
# 17                                Qureos Recruitment             9.0      Yes
# 18                                               NaN             7.0      NaN
# 19                                Qureos Recruitment             9.0      Yes
# 20                       ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 21                                Qureos Recruitment             9.0      Yes
# 22                       ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 23                       ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes
# 24                                               NaN             NaN      NaN
# 25                       ADEKA AL OTAIBA MIDDLE EAST             9.0      Y
# 29                0.00%  2023-09-30 22:49:30               3
#
#    ProfileCompletion signup_date_same application_same
# 0              58.33       2023-09-27          applied
# 1               0.00       2023-09-26      Not applied
# 2             100.00       2023-09-26          applied
# 3             100.00       2023-09-25          applied
# 4              66.67       2023-09-25          applied
# 5              58.33       2023-09-25          applied
# 6              66.67       2023-09-25          applied
# 7               0.00       2023-09-25      Not applied
# 8               0.00       2023-09-24      Not applied
# 9             100.00       2023-09-24          applied
# 10            100.00       2023-09-24          applied
# 11            100.00       2023-09-24          applied
# 12            100.00       2023-09-24      Not applied
# 13            100.00       2023-09-24          applied
# 14              0.00       2023-09-23      Not applied
# 15            100.00       2023-09-23          applied
# 16              0.00       2023-09-23      Not applied
# 17            100.00       2023-09-23          applied
# 18             33.33       2023-09-23      Not applied
# 19            100.00       2023-09-23          applied
# 20            100.00       2023-09-23          applied
# 21            100.00       2023-09-23          applied
# 22            100.00       2023-09-23          applied
# 23            100.00       2023-09-23          applied
# 24              0.00       2023-09-23      Not applied
# 25            100.00       2023-09-23          applied
# 26            100.00       2023-09-16          applied
# 27             50.00       2023-09-16      Not applied
# 28            100.00       2023-09-16          applied
# 29              0.00       2023-09-12      Not applied
#
# [30 rows x 43 columns]

# %%
# df_new.to_csv("FILES/Applicants_new.csv", index = False)

# %%
# df_old = pd.read_csv("FILES/Applicants_old.csv")
# df_new = pd.read_csv("FILES/Applicants_new.csv")

# %%
""""
updated_records = []

for index, row_old in df_old.iterrows():
    _id = row_old["_id"]

    if _id in df_new["_id"].values:
        row_new = df_new[df_new["_id"] == _id].iloc[0]
        
#         # Extract desired columns from df_new
        profile_completion_percent = row_new["Profile Completion %"]
        profile_completion = row_new["ProfileCompletion"]
        
#         # Update the relevant columns in the old row
        row_old["Profile Completion %"] = profile_completion_percent
        row_old["ProfileCompletion"] = profile_completion
    
    # Append the updated row to the list
    updated_records.append(row_old)

updated_df = pd.concat(updated_records, axis=1).T

# Export updated dataframe as CSV
updated_df.to_csv("FILES/Applicants_old.csv", index=False)
updated_df
"""
# Out:
# '"\nupdated_records = []\n\nfor index, row_old in df_old.iterrows():\n    _id = row_old["_id"]\n\n    if _id in df_new["_id"].values:\n        row_new = df_new[df_new["_id"] == _id].iloc[0]\n        \n#         # Extract desired columns from df_new\n        profile_completion_percent = row_new["Profile Completion %"]\n        profile_completion = row_new["ProfileCompletion"]\n        \n#         # Update the relevant columns in the old row\n        row_old["Profile Completion %"] = profile_completion_percent\n        row_old["ProfileCompletion"] = profile_completion\n    \n    # Append the updated row to the list\n    updated_records.append(row_old)\n\nupdated_df = pd.concat(updated_records, axis=1).T\n\n# Export updated dataframe as CSV\nupdated_df.to_csv("FILES/Applicants_old.csv", index=False)\nupdated_df\n'
