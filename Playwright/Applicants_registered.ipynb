# %%
import gspread
import pandas as pd
import openpyxl
import datetime

# %%
gc = gspread.oauth()
sh = gc.open("Associate: Ashar Saleem")
print(sh)
spreadsheet_data = gc.export(sh.id,gspread.utils.ExportFormat.CSV)
print("Excel created")

FILE_NAME = "FILES/Dashboard.csv"
SHEET = ""
FULLNAME = "Ashar Saleem"

# Write the binary data to a file
with open(FILE_NAME, 'wb') as file:
    file.write(spreadsheet_data)
# Out:
# <Spreadsheet 'Associate: Ashar Saleem' id:1ASWbNa3Yd0q4vac-0_i3vupPcfgVOMUM5hAKOHjgHeY>
# Excel created

# %%
df_new = pd.read_csv("FILES/Dashboard.csv", parse_dates=['signup_date'])
print(df_new.shape)
df_new = df_new.drop_duplicates(keep= "first", subset = "_id")
print(df_new.shape)
df_new.head()
# Out:
# (400, 37)
# (346, 37)
#                         _id          full_name signup_date  referrer_name  \
# 0  649825e637ce31001d249e52     Ricky Ramadhan  2023-06-25            NaN
# 1  64f34d6a675141001d126e8f  Dhinesh Natarajan  2023-09-02            NaN
# 2  651a86c56bf12a001ddfd563      Ahmad Dalanny  2023-10-02            NaN
# 3  64a28d791b4a4b001d1f23df        Ali Maqbool  2023-07-03            NaN
# 4  64ce1e53bff6d3001d1cc63a       Sherif Sameh  2023-08-05            NaN
#
#    application                        title                     name  \
# 0      applied  Senior Marketing Specialist           Perfect Purity
# 1      applied  Market Intelligence Manager  Dhofar Global Tr Co LLC
# 2  Not applied                          NaN                      NaN
# 3      applied               UI/UX Designer         Venture Republic
# 4      applied     Cloud Solutions Engineer           Sahara Net Co.
#
#    onboardingstep aboutme1 profileheadline  ... gender photo phone_number  \
# 0            13.0      Yes             Yes  ...    Yes   Yes          Yes
# 1             9.0      Yes             NaN  ...    NaN   NaN          Yes
# 2             6.0      NaN             NaN  ...    NaN   NaN          Yes
# 3            13.0      Yes             NaN  ...    Yes   NaN          Yes
# 4             9.0      Yes             NaN  ...    NaN   NaN          Yes
#
#   languages secondaryemail whatsappnumber interested_in is_visa_required  \
# 0       Yes            Yes            Yes           Yes              Yes
# 1       NaN            Yes            Yes           Yes              Yes
# 2       NaN            Yes            Yes           NaN              NaN
# 3       NaN            NaN            NaN           NaN              Yes
# 4       NaN            NaN            NaN           Yes              Yes
#
#   salary_range Profile Completion %
# 0          NaN               91.67%
# 1          Yes              100.00%
# 2          Yes               41.67%
# 3          Yes               83.33%
# 4          Yes              100.00%
#
# [5 rows x 37 columns]

# %%
# df_new['Current_Time'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# df_new['Remaining Count'] = 3

df_new['ProfileCompletion'] = pd.to_numeric(df_new['Profile Completion %'].str.split('%', expand=True)[0].str.split('.', expand=True)[0])
df_new = df_new.sort_values(by=['signup_date'], axis=0, ascending=False)

# %% [markdown]
# ### How many new applicants in one week span

# %%
today = datetime.date.today()
PreviousMonday = today - datetime.timedelta(days=today.weekday(), weeks=1)

print(str(PreviousMonday))
PreviousMonday = "2023-10-01"
print(df_new[df_new['signup_date'] >= str(PreviousMonday)].shape)
# df_new[df_new['signup_date'] >= "2023-07-26" ]
# df_new[ (df_new['signup_date'] >= "2023-07-1") & (df_new['ProfileCompletion'] == 100)] .shape
df_new.loc[:,'signup_date_same'] = df_new['signup_date']
df_new.loc[:,'application_same'] = df_new['application']
df_new = df_new[df_new['signup_date'] >= str(PreviousMonday)]
# Out:
# 2023-09-25
# (44, 38)

# %%
df_new2 = df_new[df_new['ProfileCompletion'] == 100].reset_index(drop=True)
# df_new2 = df_new[df_new['onboardingstep'] == 13].reset_index(drop=True)
# df_new2 = df_new[df_new['application'] == 'applied'].reset_index(drop=True)
# df_new2 = df_new[(df_new['ProfileCompletion'] == 100)  & (df_new['application'] == 'applied')] .reset_index(drop=True)
print("After -1:", len(df_new2)-1)
df_new.reset_index()
# Out:
# After -1: 3
#     index                       _id                full_name signup_date  \
# 0     250  65225d14f5f1bd001dfdb1aa            Sujin M Jinna  2023-10-08
# 1     397  652266c20f2030001dabab24            sarika tamang  2023-10-08
# 2     134  65222e17068ba9001d415821          Dilona Mendonca  2023-10-08
# 3      79  65222f4099106b001db142ae         Maitha Albalushi  2023-10-08
# 4     399  65217a716ba086001cff4930    Umar Iftikhar Saleemi  2023-10-07
# 5     307  6521799e605b8d001d8c043e             Shelden Dias  2023-10-07
# 6      80  652179d492a057001dddb6ea            isuri Lakmini  2023-10-07
# 7      29  6521985b6dcc31001df267df               Ashly Baby  2023-10-07
# 8     326  652168470f2030001daa7c71        AKSHARA VASUDEVAN  2023-10-07
# 9     227  6521491a9fcd09001d4a906e                Hussam Sa  2023-10-07
# 10     75  65217a1531ac43001d3b6ae9              vaibhav rao  2023-10-07
# 11    240  652153b0cf5f10001d03b3b7         Sumayya Al Hinai  2023-10-07
# 12    239  65214a7fa55af9001db9ee85                 Balu SPB  2023-10-07
# 13    277  65215337a7d8c0001dac684e               Ammar Butt  2023-10-07
# 14     37  65215219aa9cf4001d43d81f             Muzamil Khan  2023-10-07
# 15     38  65217e8ede5822001dc444df            Litika Chawla  2023-10-07
# 16    291  652154afaa9cf4001d43da84       Arslan Shafique Ch  2023-10-07
# 17    284  652155f5918aa6001d014d1e       Sumaiya Al-Adhoobi  2023-10-07
# 18    355  65215ec983b167001cade8c2            Muhammad Khan  2023-10-07
# 19    226  65219df36ba086001cff9801          Mostafa Harhash  2023-10-07
# 20     57  652183009fcd09001d4b032b  Kamardeen Mohamed Afzal  2023-10-07
# 21    185  65217922746003001d6a5972               Emna Mejri  2023-10-07
# 22    365  65214a6ba55af9001db9ee82            Khalil Talaat  2023-10-07
# 23     95  65217299047c38001e9c3dfc          Saeeda Almatani  2023-10-07
# 24     96  65217c8acb9213001dda1159              amr masrani  2023-10-07
# 25    374  65214f03746003001d6a1a47               ari haranv  2023-10-07
# 26     97  6521787431ac43001d3b69ba           Mehreen Khalid  2023-10-07
# 27    178  6521550c883d98001d8a660f     DILEEP SINGH.G singh  2023-10-07
# 28    200  6521a040316410001dc36685            Afreen Shaikh  2023-10-07
# 29    162  65214886746003001d6a1480            Ahmed Abdalla  2023-10-07
# 30    130  65216047708bff001e70338d           Ahlam Alaisaee  2023-10-07
# 31    248  651cfe6af37a57001df79846             Afnan Mardhi  2023-10-04
# 32     60  651d0221047c38001e9893a1           Mahmoud Soubra  2023-10-04
# 33    101  651b5c2679d97a001df8c34e           Tharshoom Sait  2023-10-03
# 34    127  651bc6e0da979d001cf20216      Abdulrahman Abouaid  2023-10-03
# 35      2  651a86c56bf12a001ddfd563            Ahmad Dalanny  2023-10-02
# 36    165  651a9ea8fb3859001df183e9         Mohannad Mohamed  2023-10-02
# 37    139  651a83ab3a6968001d3bc5a0             Aquib Dalwai  2023-10-02
# 38    142  651a6a97338042001db23b20          Mithilesh Kumar  2023-10-02
# 39    206  65196c1960cf23001d0ffba2        Shoukath Mohammed  2023-10-01
# 40    244  65198dcc501eca001d3209ed              Meera Sahib  2023-10-01
# 41    385  651957c9f7f452001d132e04           Jawad Ali Khan  2023-10-01
# 42    319  6518db0fc02bbc001dca4a58            Shubham Singh  2023-10-01
# 43    297  6518ef9c81a4ad001d5f44ca           Ranotosh Ghosh  2023-10-01
#
#     referrer_name  application                           title  \
# 0             NaN  Not applied                             NaN
# 1             NaN  Not applied                             NaN
# 2             NaN  Not applied                             NaN
# 3             NaN  Not applied                             NaN
# 4             NaN      applied            Accountant Assistant
# 5             NaN  Not applied                             NaN
# 6             NaN  Not applied                             NaN
# 7             NaN  Not applied                             NaN
# 8             NaN  Not applied                             NaN
# 9             NaN  Not applied                             NaN
# 10            NaN  Not applied                             NaN
# 11            NaN  Not applied                             NaN
# 12            NaN      applied            Accountant Assistant
# 13            NaN      applied            Accountant Assistant
# 14            NaN      applied            Accountant Assistant
# 15            NaN  Not applied                             NaN
# 16            NaN  Not applied                             NaN
# 17            NaN  Not applied                             NaN
# 18            NaN      applied            Accountant Assistant
# 19            NaN  Not applied                             NaN
# 20            NaN      applied             Executive Assistant
# 21            NaN  Not applied                             NaN
# 22            NaN  Not applied                             NaN
# 23            NaN  Not applied                             NaN
# 24            NaN  Not applied                             NaN
# 25            NaN  Not applied                             NaN
# 26            NaN  Not applied                             NaN
# 27            NaN  Not applied                             NaN
# 28            NaN  Not applied                             NaN
# 29            NaN      applied            Accountant Assistant
# 30            NaN  Not applied                             NaN
# 31            NaN  Not applied                             NaN
# 32            NaN  Not applied                             NaN
# 33            NaN  Not applied                             NaN
# 34            NaN      applied  Business Development Executive
# 35            NaN  Not applied                             NaN
# 36            NaN  Not applied                             NaN
# 37            NaN  Not applied                             NaN
# 38            NaN      applied           Social Media Marketer
# 39            NaN      applied            Accountant Assistant
# 40            NaN      applied                      Accountant
# 41            NaN  Not applied                             NaN
# 42            NaN      applied  Business Development Executive
# 43            NaN      applied  Business Development Executive
#
#                        name  onboardingstep aboutme1  ... languages  \
# 0                       NaN             9.0      NaN  ...       NaN
# 1                       NaN             2.0      NaN  ...       NaN
# 2                       NaN             7.0      NaN  ...       NaN
# 3                       NaN             6.0      NaN  ...       NaN
# 4   Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 5                       NaN             9.0      NaN  ...       NaN
# 6                       NaN             6.0      NaN  ...       NaN
# 7                       NaN             5.0      NaN  ...       NaN
# 8                       NaN             9.0      NaN  ...       NaN
# 9                       NaN             7.0      NaN  ...       NaN
# 10                      NaN             3.0      NaN  ...       NaN
# 11                      NaN             6.0      NaN  ...       NaN
# 12  Dhofar Global Tr Co LLC             9.0      NaN  ...       NaN
# 13  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 14  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 15                      NaN             9.0      NaN  ...       NaN
# 16                      NaN             5.0      NaN  ...       NaN
# 17                      NaN             3.0      NaN  ...       NaN
# 18  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 19                      NaN             9.0      NaN  ...       NaN
# 20       Qureos Recruitment             9.0      Yes  ...       NaN
# 21                      NaN             9.0      NaN  ...       NaN
# 22                      NaN             9.0      NaN  ...       NaN
# 23                      NaN             9.0      NaN  ...       NaN
# 24                      NaN             2.0      NaN  ...       NaN
# 25                      NaN             1.0      NaN  ...       NaN
# 26                      NaN             3.0      NaN  ...       NaN
# 27                      NaN             9.0      NaN  ...       NaN
# 28                      NaN             9.0      NaN  ...       NaN
# 29  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 30                      NaN             5.0      NaN  ...       NaN
# 31                      NaN             9.0      NaN  ...       NaN
# 32                      NaN             1.0      NaN  ...       NaN
# 33                      NaN             1.0      NaN  ...       NaN
# 34  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 35                      NaN             6.0      NaN  ...       NaN
# 36                      NaN             2.0      NaN  ...       NaN
# 37                      NaN             NaN      NaN  ...       NaN
# 38             Tech Inferno             9.0      Yes  ...       NaN
# 39  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 40     Alzayani Investments             9.0      Yes  ...       NaN
# 41                      NaN             9.0      Yes  ...       NaN
# 42  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
# 43  Dhofar Global Tr Co LLC             9.0      Yes  ...       NaN
#
#    secondaryemail whatsappnumber interested_in is_visa_required salary_range  \
# 0             NaN            Yes           NaN              NaN          Yes
# 1             NaN            NaN           NaN              NaN          NaN
# 2             Yes            NaN           NaN              NaN          Yes
# 3             NaN            NaN           NaN              NaN          NaN
# 4             NaN            Yes           NaN              NaN          NaN
# 5             Yes            Yes           NaN              NaN          Yes
# 6             NaN            Yes           NaN              NaN          NaN
# 7             NaN            Yes           NaN              NaN          NaN
# 8             NaN            NaN           NaN              NaN          NaN
# 9             Yes            Yes           NaN              NaN          NaN
# 10            NaN            NaN           NaN              NaN          NaN
# 11            Yes            NaN           NaN              NaN          Yes
# 12            Yes            Yes           NaN              NaN          Yes
# 13            Yes            Yes           NaN              NaN          Yes
# 14            NaN            NaN           NaN              NaN          NaN
# 15            Yes            Yes           NaN              NaN          NaN
# 16            NaN            Yes           NaN              NaN          NaN
# 17            NaN            NaN           NaN              NaN          NaN
# 18            Yes            NaN           NaN              NaN          NaN
# 19            NaN            NaN           NaN              NaN          NaN
# 20            NaN            Yes           NaN              NaN          Yes
# 21            Yes            NaN           NaN              NaN          NaN
# 22            Yes            Yes           NaN              NaN          NaN
# 23            NaN            Yes           NaN              NaN          NaN
# 24            NaN            NaN           NaN              NaN          NaN
# 25            NaN            Yes           NaN              NaN          NaN
# 26            NaN            Yes           NaN              NaN          NaN
# 27            NaN            NaN           NaN              NaN          NaN
# 28            NaN            NaN           NaN              NaN          Yes
# 29            Yes            Yes           NaN              NaN          NaN
# 30            NaN            Yes           NaN              NaN          NaN
# 31            NaN            NaN           NaN              NaN          Yes
# 32            NaN            NaN           NaN              NaN          NaN
# 33            NaN            Yes           NaN              NaN          NaN
# 34            NaN            Yes           NaN              NaN          NaN
# 35            Yes            Yes           NaN              NaN          Yes
# 36            Yes            Yes           NaN              NaN          NaN
# 37            NaN            NaN           NaN              NaN          NaN
# 38            NaN            NaN           Yes              Yes          Yes
# 39            NaN            NaN           Yes              Yes          Yes
# 40            Yes            NaN           NaN              NaN          NaN
# 41            Yes            Yes           Yes              Yes          Yes
# 42            Yes            Yes           NaN              NaN          NaN
# 43            Yes            Yes           Yes              Yes          Yes
#
#    Profile Completion % ProfileCompletion signup_date_same application_same
# 0                58.33%                58       2023-10-08      Not applied
# 1                 0.00%                 0       2023-10-08      Not applied
# 2                41.67%                41       2023-10-08      Not applied
# 3                25.00%                25       2023-10-08      Not applied
# 4                58.33%                58       2023-10-07          applied
# 5                58.33%                58       2023-10-07      Not applied
# 6                33.33%                33       2023-10-07      Not applied
# 7                16.67%                16       2023-10-07      Not applied
# 8                50.00%                50       2023-10-07      Not applied
# 9                41.67%                41       2023-10-07      Not applied
# 10                8.33%                 8       2023-10-07      Not applied
# 11               41.67%                41       2023-10-07      Not applied
# 12               58.33%                58       2023-10-07          applied
# 13               83.33%                83       2023-10-07          applied
# 14               41.67%                41       2023-10-07          applied
# 15               50.00%                50       2023-10-07      Not applied
# 16               25.00%                25       2023-10-07      Not applied
# 17                0.00%                 0       2023-10-07      Not applied
# 18               58.33%                58       2023-10-07          applied
# 19               50.00%                50       2023-10-07      Not applied
# 20               66.67%                66       2023-10-07          applied
# 21               50.00%                50       2023-10-07      Not applied
# 22               41.67%                41       2023-10-07      Not applied
# 23               50.00%                50       2023-10-07      Not applied
# 24                0.00%                 0       2023-10-07      Not applied
# 25               50.00%                50       2023-10-07      Not applied
# 26               33.33%                33       2023-10-07      Not applied
# 27               50.00%                50       2023-10-07      Not applied
# 28               58.33%                58       2023-10-07      Not applied
# 29               58.33%                58       2023-10-07          applied
# 30                8.33%                 8       2023-10-07      Not applied
# 31               50.00%                50       2023-10-04      Not applied
# 32                0.00%                 0       2023-10-04      Not applied
# 33               41.67%                41       2023-10-03      Not applied
# 34               58.33%                58       2023-10-03          applied
# 35               41.67%                41       2023-10-02      Not applied
# 36               50.00%                50       2023-10-02      Not applied
# 37                0.00%                 0       2023-10-02      Not applied
# 38              100.00%               100       2023-10-02          applied
# 39              100.00%               100       2023-10-01          applied
# 40               58.33%                58       2023-10-01          applied
# 41              100.00%               100       2023-10-01      Not applied
# 42               58.33%                58       2023-10-01          applied
# 43              100.00%               100       2023-10-01          applied
#
# [44 rows x 41 columns]

# %%
# df_new.to_csv("FILES/Applicants_new.csv", index = False)

# %%
# df_old = pd.read_csv("FILES/Applicants_old.csv")
# df_new = pd.read_csv("FILES/Applicants_new.csv")

# %%
""""
updated_records = []

for index, row_old in df_old.iterrows():
    _id = row_old["_id"]

    if _id in df_new["_id"].values:
        row_new = df_new[df_new["_id"] == _id].iloc[0]
        
#         # Extract desired columns from df_new
        profile_completion_percent = row_new["Profile Completion %"]
        profile_completion = row_new["ProfileCompletion"]
        
#         # Update the relevant columns in the old row
        row_old["Profile Completion %"] = profile_completion_percent
        row_old["ProfileCompletion"] = profile_completion
    
    # Append the updated row to the list
    updated_records.append(row_old)

updated_df = pd.concat(updated_records, axis=1).T

# Export updated dataframe as CSV
updated_df.to_csv("FILES/Applicants_old.csv", index=False)
updated_df
"""
# Out:
# '"\nupdated_records = []\n\nfor index, row_old in df_old.iterrows():\n    _id = row_old["_id"]\n\n    if _id in df_new["_id"].values:\n        row_new = df_new[df_new["_id"] == _id].iloc[0]\n        \n#         # Extract desired columns from df_new\n        profile_completion_percent = row_new["Profile Completion %"]\n        profile_completion = row_new["ProfileCompletion"]\n        \n#         # Update the relevant columns in the old row\n        row_old["Profile Completion %"] = profile_completion_percent\n        row_old["ProfileCompletion"] = profile_completion\n    \n    # Append the updated row to the list\n    updated_records.append(row_old)\n\nupdated_df = pd.concat(updated_records, axis=1).T\n\n# Export updated dataframe as CSV\nupdated_df.to_csv("FILES/Applicants_old.csv", index=False)\nupdated_df\n'
