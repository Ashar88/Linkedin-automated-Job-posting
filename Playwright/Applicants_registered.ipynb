# %%
import gspread
import pandas as pd
import openpyxl
import datetime

# %%
gc = gspread.oauth()
sh = gc.open("Associate: Ashar Saleem")
print(sh)
spreadsheet_data = gc.export(sh.id,gspread.utils.ExportFormat.CSV)
print("Excel created")

FILE_NAME = "FILES/Dashboard.csv"
SHEET = ""
FULLNAME = "Ashar Saleem"

# Write the binary data to a file
with open(FILE_NAME, 'wb') as file:
    file.write(spreadsheet_data)
# Out:
# <Spreadsheet 'Associate: Ashar Saleem' id:1ASWbNa3Yd0q4vac-0_i3vupPcfgVOMUM5hAKOHjgHeY>
# Excel created

# %%
df_new = pd.read_csv("FILES/Dashboard.csv", parse_dates=['signup_date'])
print(df_new.shape)
df_new = df_new.drop_duplicates(keep= "first", subset = "_id")
print(df_new.shape)
df_new.head()
# Out:
# (355, 37)
# (308, 37)
#                         _id      full_name signup_date  referrer_name  \
# 0  64e932c174082b001efec5b2    Mahmoud Ali  2023-08-25            NaN
# 1  64c2a7db810f40001d1c28b1       Arun v v  2023-07-27            NaN
# 2  64a580b812d25b001d798a57    Ubaid Mufti  2023-07-05            NaN
# 3  64a568e9fa84ef001e82510e   Fatima Zahid  2023-07-05            NaN
# 4  6511d846e2772d001de51744  Alex Varghese  2023-09-25            NaN
#
#    application                  title                         name  \
# 0  Not applied                    NaN                          NaN
# 1  Not applied                    NaN                          NaN
# 2      applied         UI/UX Designer             Venture Republic
# 3  Not applied                    NaN                          NaN
# 4      applied  Procurement Assistant  ADEKA AL OTAIBA MIDDLE EAST
#
#    onboardingstep aboutme1 profileheadline  ... gender photo phone_number  \
# 0             9.0      Yes             NaN  ...    NaN   NaN          Yes
# 1             9.0      NaN             NaN  ...    NaN   NaN          NaN
# 2            13.0      Yes             NaN  ...    Yes   Yes          Yes
# 3            13.0      Yes             NaN  ...    Yes   Yes          Yes
# 4             9.0      Yes             NaN  ...    NaN   NaN          Yes
#
#   languages secondaryemail whatsappnumber interested_in is_visa_required  \
# 0       NaN            NaN            Yes           Yes              Yes
# 1       NaN            NaN            NaN           NaN              NaN
# 2       NaN            Yes            NaN           NaN              Yes
# 3       Yes            Yes            Yes           NaN              Yes
# 4       NaN            NaN            Yes           NaN              NaN
#
#   salary_range Profile Completion %
# 0          Yes              100.00%
# 1          Yes               50.00%
# 2          Yes               83.33%
# 3          Yes               83.33%
# 4          Yes               66.67%
#
# [5 rows x 37 columns]

# %%
df_new['Current_Time'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df_new['Remaining Count'] = 3

df_new['ProfileCompletion'] = pd.to_numeric(df_new['Profile Completion %'].str.split('%', expand=True)[0])
df_new = df_new.sort_values(by=['signup_date'], axis=0, ascending=False)

# %% [markdown]
# ### How many new applicants in one week span

# %%
today = datetime.date.today()
PreviousMonday = today - datetime.timedelta(days=today.weekday(), weeks=1)

print(str(PreviousMonday))
PreviousMonday = "2023-09-01"
print(df_new[df_new['signup_date'] >= str(PreviousMonday)].shape)
# df_new[df_new['signup_date'] >= "2023-07-26" ]
# df_new[ (df_new['signup_date'] >= "2023-07-1") & (df_new['ProfileCompletion'] == 100)] .shape
df_new.loc[:,'signup_date_same'] = df_new['signup_date']
df_new.loc[:,'application_same'] = df_new['application']
df_new = df_new[df_new['signup_date'] >= str(PreviousMonday)]
# Out:
# 2023-09-25
# (80, 40)

# %%
df_new2 = df_new[df_new['ProfileCompletion'] == 100].reset_index(drop=True)
# df_new2 = df_new[df_new['onboardingstep'] == 13].reset_index(drop=True)
# df_new2 = df_new[df_new['application'] == 'applied'].reset_index(drop=True)
# df_new2 = df_new[(df_new['ProfileCompletion'] == 100)  & (df_new['application'] == 'applied')] .reset_index(drop=True)
print(len(df_new2)-3)
df_new.reset_index()[:40]
# Out:
# 44
#     index                       _id                 full_name signup_date  \
# 0      65  651a6a97338042001db23b20           Mithilesh Kumar  2023-10-02
# 1     118  6518db0fc02bbc001dca4a58             Shubham Singh  2023-10-01
# 2     343  651957c9f7f452001d132e04            Jawad Ali Khan  2023-10-01
# 3     108  65198dcc501eca001d3209ed               Meera Sahib  2023-10-01
# 4     120  65196c1960cf23001d0ffba2         Shoukath Mohammed  2023-10-01
# 5      50  6518ef9c81a4ad001d5f44ca            Ranotosh Ghosh  2023-10-01
# 6     233  651854b72dbd11001d2bb3a5      Georjedine Jeanlouis  2023-09-30
# 7     330  6518623db1da38001dcd8fb7                 Yara Mhmd  2023-09-30
# 8      73  6518558d4f56e3001d0a2e99             Hassan Algain  2023-09-30
# 9      22  651854bae2b036001ee3e874          Ahmed Abdelrazik  2023-09-30
# 10    175  65185732519db2001d548bd9               Eslam Morsy  2023-09-30
# 11    336  65186692e34bdb001d3aee4e          Ashly Sara Koshy  2023-09-30
# 12    335  651885bf3689f2001d7c95c4  Sayed hassan sayed Ahmed  2023-09-30
# 13     48  651857522b7065001ddaca54              Mehsab Ali e  2023-09-30
# 14    242  651873621f6eb0001d94d1b2                Yehya Asal  2023-09-30
# 15    337  65185c2b2dbd11001d2bb56d             Eslam Mohamed  2023-09-30
# 16    322  65185aaee34bdb001d3adb5a                Duha Saeed  2023-09-30
# 17     59  6513ecba5b38f7001d6c200d            Mohammed Bayaz  2023-09-27
# 18    195  6512ca5f881c9b001d4fec37                 Safvan Vt  2023-09-26
# 19    111  651274bbef73aa001da534d3           Mohammad Bashar  2023-09-26
# 20    136  6511def666c03e001dbe2f73       Kartiksingh Hushare  2023-09-25
# 21    172  6511e08a4786f9001d29fc15    Edward Jerameel Martin  2023-09-25
# 22      4  6511d846e2772d001de51744             Alex Varghese  2023-09-25
# 23      9  651111f79348f0001d78c621               AMALNADH NJ  2023-09-25
# 24    193  65111816ebc35b001d6a123a           shafiq mohammed  2023-09-25
# 25    319  65103b5723114b001de54884            shahbaz akhter  2023-09-24
# 26    298  650fad23b9e90b001dbf9a0f            Muhammed Shafi  2023-09-24
# 27    325  650fcf78781892001ddc3d2b              nabil sayyed  2023-09-24
# 28    181  650fef4ddc22bd001dee27ce    Md. Saiful islam Ropam  2023-09-24
# 29    291  650ff6303c8e50001c2005a8           Zawar Amin khan  2023-09-24
# 30    192  650fef799348f0001d784247        Syamlal Swarnappan  2023-09-24
# 31     98  650f145b9348f0001d77f41b         Jithesh.K.P Jithu  2023-09-23
# 32    205  650f11c4ebc35b001d693ade               subin balan  2023-09-23
# 33    170  650f1454cb796e001d5df4b3          Abu Bakar Waheed  2023-09-23
# 34    188  650f3001290fef001d21d2c8       Charinette Padolina  2023-09-23
# 35    169  650f0fc1135a25001da8ca36              Rehab Tigani  2023-09-23
# 36     68  650f05c85e8136001d98b8b6        Karren Jake Aenlle  2023-09-23
# 37    160  650f2636a5d55e001d5b51fd             Arun Raghavan  2023-09-23
# 38    142  650f216f0acb7b001d9321ce            Kartik Hushare  2023-09-23
# 39    228  650f0913cb796e001d5defc4                bino benny  2023-09-23
#
#     referrer_name  application                           title  \
# 0             NaN      applied           Social Media Marketer
# 1             NaN      applied  Business Development Executive
# 2             NaN  Not applied                             NaN
# 3             NaN      applied            Accountant Assistant
# 4             NaN      applied            Accountant Assistant
# 5             NaN      applied  Business Development Executive
# 6             NaN  Not applied                             NaN
# 7             NaN  Not applied                             NaN
# 8             NaN      applied               Marketing Manager
# 9             NaN      applied  Business Development Executive
# 10            NaN      applied                      Accountant
# 11            NaN  Not applied                             NaN
# 12            NaN  Not applied                             NaN
# 13            NaN      applied                      Accountant
# 14            NaN      applied  Business Development Executive
# 15            NaN      applied            Accountant Assistant
# 16            NaN  Not applied                             NaN
# 17            NaN      applied                       Draftsman
# 18            NaN      applied       Interior Design Draftsman
# 19            NaN  Not applied                             NaN
# 20            NaN      applied             Executive Assistant
# 21            NaN      applied           Procurement Assistant
# 22            NaN      applied           Procurement Assistant
# 23            NaN      applied       Interior Design Draftsman
# 24            NaN      applied           Procurement Assistant
# 25            NaN      applied       Interior Design Draftsman
# 26            NaN  Not applied                             NaN
# 27            NaN      applied       Interior Design Draftsman
# 28            NaN  Not applied                             NaN
# 29            NaN      applied           Procurement Assistant
# 30            NaN      applied           Procurement Assistant
# 31            NaN  Not applied                             NaN
# 32            NaN      applied       Interior Design Draftsman
# 33            NaN  Not applied                             NaN
# 34            NaN      applied           Procurement Assistant
# 35            NaN      applied       Interior Design Draftsman
# 36            NaN      applied           Procurement Assistant
# 37            NaN  Not applied                             NaN
# 38            NaN      applied           Procurement Assistant
# 39            NaN      applied           Procurement Assistant
#
#                            name  onboardingstep aboutme1  ... whatsappnumber  \
# 0                  Tech Inferno             9.0      NaN  ...            NaN
# 1       Dhofar Global Tr Co LLC             9.0      Yes  ...            Yes
# 2                           NaN             9.0      NaN  ...            Yes
# 3            Qureos Recruitment             9.0      NaN  ...            NaN
# 4            Qureos Recruitment             9.0      Yes  ...            NaN
# 5       Dhofar Global Tr Co LLC             9.0      Yes  ...            Yes
# 6                           NaN             5.0      NaN  ...            NaN
# 7                           NaN             9.0      NaN  ...            Yes
# 8                         Atari             9.0      NaN  ...            Yes
# 9       Dhofar Global Tr Co LLC             9.0      NaN  ...            Yes
# 10         Alzayani Investments             9.0      Yes  ...            NaN
# 11                          NaN             9.0      NaN  ...            NaN
# 12                          NaN             7.0      NaN  ...            Yes
# 13         Alzayani Investments             9.0      NaN  ...            Yes
# 14      Dhofar Global Tr Co LLC             9.0      NaN  ...            NaN
# 15           Qureos Recruitment             9.0      Yes  ...            Yes
# 16                          NaN             9.0      NaN  ...            NaN
# 17           Qureos Recruitment             9.0      NaN  ...            Yes
# 18           Qureos Recruitment             9.0      Yes  ...            Yes
# 19                          NaN             2.0      NaN  ...            NaN
# 20           Qureos Recruitment             9.0      Yes  ...            Yes
# 21  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            NaN
# 22  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            Yes
# 23           Qureos Recruitment             9.0      Yes  ...            Yes
# 24  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            NaN
# 25           Qureos Recruitment             9.0      Yes  ...            NaN
# 26                          NaN             2.0      NaN  ...            NaN
# 27           Qureos Recruitment             9.0      Yes  ...            NaN
# 28                          NaN             9.0      Yes  ...            Yes
# 29  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            Yes
# 30  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            Yes
# 31                          NaN             1.0      NaN  ...            NaN
# 32           Qureos Recruitment             9.0      Yes  ...            NaN
# 33                          NaN             2.0      NaN  ...            NaN
# 34  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            NaN
# 35           Qureos Recruitment             9.0      Yes  ...            NaN
# 36  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            Yes
# 37                          NaN             7.0      NaN  ...            NaN
# 38  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            Yes
# 39  ADEKA AL OTAIBA MIDDLE EAST             9.0      Yes  ...            NaN
#
#    interested_in is_visa_required salary_range Profile Completion %  \
# 0            NaN              NaN          Yes               58.33%
# 1            NaN              NaN          NaN               58.33%
# 2            NaN              NaN          NaN               50.00%
# 3            NaN              NaN          NaN               50.00%
# 4            NaN              NaN          NaN               58.33%
# 5            Yes              Yes          Yes              100.00%
# 6            NaN              NaN          NaN               25.00%
# 7            NaN              NaN          NaN               41.67%
# 8            NaN              NaN          NaN               50.00%
# 9            NaN              NaN          NaN               41.67%
# 10           NaN              NaN          NaN               58.33%
# 11           NaN              NaN          Yes               50.00%
# 12           NaN              NaN          Yes               50.00%
# 13           NaN              NaN          NaN               50.00%
# 14           NaN              NaN          NaN               50.00%
# 15           NaN              NaN          NaN               58.33%
# 16           NaN              NaN          NaN               50.00%
# 17           NaN              NaN          Yes               58.33%
# 18           Yes              Yes          Yes              100.00%
# 19           NaN              NaN          NaN                0.00%
# 20           NaN              NaN          NaN               58.33%
# 21           NaN              NaN          Yes               66.67%
# 22           NaN              NaN          Yes               66.67%
# 23           NaN              NaN          NaN               58.33%
# 24           Yes              Yes          Yes              100.00%
# 25           Yes              Yes          Yes              100.00%
# 26           NaN              NaN          NaN                0.00%
# 27           Yes              Yes          Yes              100.00%
# 28           Yes              Yes          Yes              100.00%
# 29           Yes              Yes          Yes              100.00%
# 30           Yes              Yes          Yes              100.00%
# 31           NaN              NaN          NaN                0.00%
# 32           Yes              Yes          Yes              100.00%
# 33           NaN              NaN          NaN                0.00%
# 34           Yes              Yes          Yes              100.00%
# 35           Yes              Yes          Yes              100.00%
# 36           Yes              Yes          Yes              100.00%
# 37           NaN              NaN          NaN               33.33%
# 38           Yes              Yes          Yes              100.00%
# 39           Yes              Yes          Yes              100.00%
#
#            Current_Time Remaining Count ProfileCompletion signup_date_same  \
# 0   2023-10-02 14:53:48               3             58.33       2023-10-02
# 1   2023-10-02 14:53:48               3             58.33       2023-10-01
# 2   2023-10-02 14:53:48               3             50.00       2023-10-01
# 3   2023-10-02 14:53:48               3             50.00       2023-10-01
# 4   2023-10-02 14:53:48               3             58.33       2023-10-01
# 5   2023-10-02 14:53:48               3            100.00       2023-10-01
# 6   2023-10-02 14:53:48               3             25.00       2023-09-30
# 7   2023-10-02 14:53:48               3             41.67       2023-09-30
# 8   2023-10-02 14:53:48               3             50.00       2023-09-30
# 9   2023-10-02 14:53:48               3             41.67       2023-09-30
# 10  2023-10-02 14:53:48               3             58.33       2023-09-30
# 11  2023-10-02 14:53:48               3             50.00       2023-09-30
# 12  2023-10-02 14:53:48               3             50.00       2023-09-30
# 13  2023-10-02 14:53:48               3             50.00       2023-09-30
# 14  2023-10-02 14:53:48               3             50.00       2023-09-30
# 15  2023-10-02 14:53:48               3             58.33       2023-09-30
# 16  2023-10-02 14:53:48               3             50.00       2023-09-30
# 17  2023-10-02 14:53:48               3             58.33       2023-09-27
# 18  2023-10-02 14:53:48               3            100.00       2023-09-26
# 19  2023-10-02 14:53:48               3              0.00       2023-09-26
# 20  2023-10-02 14:53:48               3             58.33       2023-09-25
# 21  2023-10-02 14:53:48               3             66.67       2023-09-25
# 22  2023-10-02 14:53:48               3             66.67       2023-09-25
# 23  2023-10-02 14:53:48               3             58.33       2023-09-25
# 24  2023-10-02 14:53:48               3            100.00       2023-09-25
# 25  2023-10-02 14:53:48               3            100.00       2023-09-24
# 26  2023-10-02 14:53:48               3              0.00       2023-09-24
# 27  2023-10-02 14:53:48               3            100.00       2023-09-24
# 28  2023-10-02 14:53:48               3            100.00       2023-09-24
# 29  2023-10-02 14:53:48               3            100.00       2023-09-24
# 30  2023-10-02 14:53:48               3            100.00       2023-09-24
# 31  2023-10-02 14:53:48               3              0.00       2023-09-23
# 32  2023-10-02 14:53:48               3            100.00       2023-09-23
# 33  2023-10-02 14:53:48               3              0.00       2023-09-23
# 34  2023-10-02 14:53:48               3            100.00       2023-09-23
# 35  2023-10-02 14:53:48               3            100.00       2023-09-23
# 36  2023-10-02 14:53:48               3            100.00       2023-09-23
# 37  2023-10-02 14:53:48               3             33.33       2023-09-23
# 38  2023-10-02 14:53:48               3            100.00       2023-09-23
# 39  2023-10-02 14:53:48               3            100.00       2023-09-23
#
#    application_same
# 0           applied
# 1           applied
# 2       Not applied
# 3           applied
# 4           applied
# 5           applied
# 6       Not applied
# 7       Not applied
# 8           applied
# 9           applied
# 10          applied
# 11      Not applied
# 12      Not applied
# 13          applied
# 14          applied
# 15          applied
# 16      Not applied
# 17          applied
# 18          applied
# 19      Not applied
# 20          applied
# 21          applied
# 22          applied
# 23          applied
# 24          applied
# 25          applied
# 26      Not applied
# 27          applied
# 28      Not applied
# 29          applied
# 30          applied
# 31      Not applied
# 32          applied
# 33      Not applied
# 34          applied
# 35          applied
# 36          applied
# 37      Not applied
# 38          applied
# 39          applied
#
# [40 rows x 43 columns]

# %%
# df_new.to_csv("FILES/Applicants_new.csv", index = False)

# %%
# df_old = pd.read_csv("FILES/Applicants_old.csv")
# df_new = pd.read_csv("FILES/Applicants_new.csv")

# %%
""""
updated_records = []

for index, row_old in df_old.iterrows():
    _id = row_old["_id"]

    if _id in df_new["_id"].values:
        row_new = df_new[df_new["_id"] == _id].iloc[0]
        
#         # Extract desired columns from df_new
        profile_completion_percent = row_new["Profile Completion %"]
        profile_completion = row_new["ProfileCompletion"]
        
#         # Update the relevant columns in the old row
        row_old["Profile Completion %"] = profile_completion_percent
        row_old["ProfileCompletion"] = profile_completion
    
    # Append the updated row to the list
    updated_records.append(row_old)

updated_df = pd.concat(updated_records, axis=1).T

# Export updated dataframe as CSV
updated_df.to_csv("FILES/Applicants_old.csv", index=False)
updated_df
"""
# Out:
# '"\nupdated_records = []\n\nfor index, row_old in df_old.iterrows():\n    _id = row_old["_id"]\n\n    if _id in df_new["_id"].values:\n        row_new = df_new[df_new["_id"] == _id].iloc[0]\n        \n#         # Extract desired columns from df_new\n        profile_completion_percent = row_new["Profile Completion %"]\n        profile_completion = row_new["ProfileCompletion"]\n        \n#         # Update the relevant columns in the old row\n        row_old["Profile Completion %"] = profile_completion_percent\n        row_old["ProfileCompletion"] = profile_completion\n    \n    # Append the updated row to the list\n    updated_records.append(row_old)\n\nupdated_df = pd.concat(updated_records, axis=1).T\n\n# Export updated dataframe as CSV\nupdated_df.to_csv("FILES/Applicants_old.csv", index=False)\nupdated_df\n'
